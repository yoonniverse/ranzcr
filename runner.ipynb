# %% [markdown]
# # PREPROCESS

# %%
# !python preprocess.py \
--data_dir ../../input/kaggle \
--save_dir ../../input/processed/data \
--njobs 24 \
--nfolds 5 \
--compress 1
# Out:
# 100%|████████████████████████████████████| 30083/30083 [02:38<00:00, 190.04it/s]

# %% [markdown]
# # TRAIN

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v15/seg_pretrain/1024-b5 \
--seed 0 \
--batch_size 64 \
--lr 8e-4 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 15 \
--encoder timm-efficientnet-b5 \
--in_channels 8 \
--encoder_depth 5 \
--resolution 1024 \
--dropout 0.2 \
--seg_pretrain 1 \
--annotated_weight 1.0 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 1.0 \
--val_freq 1 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--use_attn 0 \
--k 128 \
--nheads 8 \
--focal 0
# Out:
# Launched gpu 0
# Launched gpu 1
# Launched gpu 3
# Launched gpu 2
# # Train Samples: 7200 | # Val Samples: 1895
# # Parameters: 31669699
# EPOCH: 0 | LRs: {3.200000000000002e-05}
# 100%|█████████████████████████████████████████| 113/113 [03:15<00:00,  1.73s/it]
# 100%|███████████████████████████████████████████| 30/30 [00:50<00:00,  1.67s/it](trn) LOSS: 0.314202 ||
# (val) LOSS: 0.08098 | METRIC: -0.08098 || Runtime: 274
# EPOCH: 1 | LRs: {0.0007934156305567665}
# (trn) LOSS: 0.058118 || (val) LOSS: 0.042677 | METRIC: -0.042677 || Runtime: 261
# EPOCH: 2 | LRs: {0.0007694676966214702}
# (trn) LOSS: 0.040449 || (val) LOSS: 0.033347 | METRIC: -0.033347 || Runtime: 268
# EPOCH: 3 | LRs: {0.0007290456865519726}
# (trn) LOSS: 0.033621 || (val) LOSS: 0.029043 | METRIC: -0.029043 || Runtime: 266
# EPOCH: 4 | LRs: {0.000673951972142254}
# (trn) LOSS: 0.030309 || (val) LOSS: 0.026404 | METRIC: -0.026404 || Runtime: 258
# EPOCH: 5 | LRs: {0.0006066431199189892}
# (trn) LOSS: 0.028533 || (val) LOSS: 0.025543 | METRIC: -0.025543 || Runtime: 272
# EPOCH: 6 | LRs: {0.000530120355613501}
# (trn) LOSS: 0.026618 || (val) LOSS: 0.023931 | METRIC: -0.023931 || Runtime: 266
# EPOCH: 7 | LRs: {0.0004477957428946779}
# (trn) LOSS: 0.026168 || (val) LOSS: 0.023127 | METRIC: -0.023127 || Runtime: 259
# EPOCH: 8 | LRs: {0.00036334004330207745}
# (trn) LOSS: 0.024999 || (val) LOSS: 0.022773 | METRIC: -0.022773 || Runtime: 265
# EPOCH: 9 | LRs: {0.00028051904113303693}
# (trn) LOSS: 0.023813 || (val) LOSS: 0.022249 | METRIC: -0.022249 || Runtime: 266
# EPOCH: 10 | LRs: {0.00020302563137229298}
# (trn) LOSS: 0.022789 || (val) LOSS: 0.021996 | METRIC: -0.021996 || Runtime: 273
# EPOCH: 11 | LRs: {0.0001343151576737595}
# (trn) LOSS: 0.022253 || (val) LOSS: 0.021644 | METRIC: -0.021644 || Runtime: 260
# EPOCH: 12 | LRs: {7.74513424879606e-05}
# (trn) LOSS: 0.02243 || (val) LOSS: 0.02149 | METRIC: -0.02149 || Runtime: 270
# EPOCH: 13 | LRs: {3.4969679136795436e-05}
# (trn) LOSS: 0.022004 || (val) LOSS: 0.021336 | METRIC: -0.021336 || Runtime: 261
# EPOCH: 14 | LRs: {8.764377028797835e-06}
# (trn) LOSS: 0.022013 || (val) LOSS: 0.021313 | METRIC: -0.021313 || Runtime: 263
# Best Val Score: -0.021313117955636847
# Runtime: 3990

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v15/1024-b5 \
--seed 0 \
--batch_size 64 \
--lr 8e-4 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 15 \
--encoder timm-efficientnet-b5 \
--in_channels 8 \
--encoder_depth 5 \
--resolution 1024 \
--dropout 0.2 \
--seg_pretrain 0 \
--annotated_weight 1.0 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 1.0 \
--val_freq 1 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--pretrained_path ../../model/v15/seg_pretrain/1024-b5/best.pth \
--use_attn 0 \
--k 128 \
--nheads 8 \
--focal 0
# Out:
# Launched gpu 0
# Launched gpu 1
# Launched gpu 2
# Launched gpu 3
# # Train Samples: 24066 | # Val Samples: 6017
# # Parameters: 31669699
# <All keys matched successfully>
# Loaded Pretrained Weights from ../../model/v15/seg_pretrain/1024-b5/best.pth
# EPOCH: 0 | LRs: {3.200000000000002e-05}
# 100%|█████████████████████████████████████████| 377/377 [05:55<00:00,  1.06it/s]
# 100%|███████████████████████████████████████████| 95/95 [01:11<00:00,  1.33it/s](trn) LOSS: 0.235701 ||
# (val) LOSS: 0.169663 | METRIC: 0.916651 || Runtime: 456
# EPOCH: 1 | LRs: {0.0007935100500584229}
# (trn) LOSS: 0.180244 || (val) LOSS: 0.158997 | METRIC: 0.924653 || Runtime: 457
# EPOCH: 2 | LRs: {0.0007696683260999016}
# (trn) LOSS: 0.171408 || (val) LOSS: 0.153689 | METRIC: 0.935707 || Runtime: 449
# EPOCH: 3 | LRs: {0.0007293435801652396}
# (trn) LOSS: 0.163645 || (val) LOSS: 0.144076 | METRIC: 0.94046 || Runtime: 450
# EPOCH: 4 | LRs: {0.000674333847150452}
# (trn) LOSS: 0.157851 || (val) LOSS: 0.138772 | METRIC: 0.945341 || Runtime: 448
# EPOCH: 5 | LRs: {0.0006070919489466262}
# (trn) LOSS: 0.152198 || (val) LOSS: 0.13731 | METRIC: 0.94788 || Runtime: 448
# EPOCH: 6 | LRs: {0.0005306161258809468}
# (trn) LOSS: 0.146712 || (val) LOSS: 0.136315 | METRIC: 0.949747 || Runtime: 447
# EPOCH: 7 | LRs: {0.0004483163485654142}
# (trn) LOSS: 0.14123 || (val) LOSS: 0.13574 | METRIC: 0.952255 || Runtime: 449
# EPOCH: 8 | LRs: {0.0003638622711569913}
# (trn) LOSS: 0.134881 || (val) LOSS: 0.134547 | METRIC: 0.951948 || Runtime: 448
# EPOCH: 9 | LRs: {0.0002810196056216548}
# (trn) LOSS: 0.128849 || (val) LOSS: 0.132178 | METRIC: 0.952998 || Runtime: 449
# EPOCH: 10 | LRs: {0.0002034822128891869}
# (trn) LOSS: 0.123178 || (val) LOSS: 0.132719 | METRIC: 0.953636 || Runtime: 448
# EPOCH: 11 | LRs: {0.00013470739776455545}
# (trn) LOSS: 0.118799 || (val) LOSS: 0.13155 | METRIC: 0.954323 || Runtime: 449
# EPOCH: 12 | LRs: {7.776175160983506e-05}
# (trn) LOSS: 0.115964 || (val) LOSS: 0.132849 | METRIC: 0.95366 || Runtime: 449
# EPOCH: 13 | LRs: {3.51844164974451e-05}
# (trn) LOSS: 0.112499 || (val) LOSS: 0.13251 | METRIC: 0.954548 || Runtime: 448
# EPOCH: 14 | LRs: {8.87386773174224e-06}
# (trn) LOSS: 0.110437 || (val) LOSS: 0.132756 | METRIC: 0.954086 || Runtime: 447
# Best Val Score: 0.9545475923758978
# Runtime: 6749

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v15/seg_pretrain/1024-b5-nodownconv \
--seed 0 \
--batch_size 16 \
--lr 3e-4 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 15 \
--encoder timm-efficientnet-b5 \
--in_channels 8 \
--encoder_depth 5 \
--resolution 1024 \
--dropout 0.2 \
--seg_pretrain 1 \
--annotated_weight 1.0 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 1.0 \
--val_freq 1 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--use_attn 0 \
--k 128 \
--nheads 8 \
--focal 0 \
--downconv 0
# Out:
# Launched gpu 1
# Launched gpu 2
# Launched gpu 3
# Launched gpu 0
# # Train Samples: 7200 | # Val Samples: 1895
# # Parameters: 31666486
# EPOCH: 0 | LRs: {1.200000000000002e-05}
# 100%|█████████████████████████████████████████| 450/450 [06:05<00:00,  1.23it/s]
# 100%|█████████████████████████████████████████| 119/119 [01:14<00:00,  1.59it/s](trn) LOSS: 0.249547 ||
# (val) LOSS: 0.060623 | METRIC: -0.060623 || Runtime: 471
# EPOCH: 1 | LRs: {0.0002975687178988091}
# (trn) LOSS: 0.043682 || (val) LOSS: 0.030569 | METRIC: -0.030569 || Runtime: 452
# EPOCH: 2 | LRs: {0.0002886308375352552}
# (trn) LOSS: 0.030343 || (val) LOSS: 0.023787 | METRIC: -0.023787 || Runtime: 451
# EPOCH: 3 | LRs: {0.0002735115913886372}
# (trn) LOSS: 0.02663 || (val) LOSS: 0.021786 | METRIC: -0.021786 || Runtime: 451
# EPOCH: 4 | LRs: {0.0002528851295755391}
# (trn) LOSS: 0.024053 || (val) LOSS: 0.019962 | METRIC: -0.019962 || Runtime: 451
# EPOCH: 5 | LRs: {0.00022767116274166122}
# (trn) LOSS: 0.022304 || (val) LOSS: 0.019129 | METRIC: -0.019129 || Runtime: 448
# EPOCH: 6 | LRs: {0.0001989939532024497}
# (trn) LOSS: 0.021282 || (val) LOSS: 0.018953 | METRIC: -0.018953 || Runtime: 448
# EPOCH: 7 | LRs: {0.00016813218535570326}
# (trn) LOSS: 0.020651 || (val) LOSS: 0.018184 | METRIC: -0.018184 || Runtime: 451
# EPOCH: 8 | LRs: {0.00013646195058786433}
# (trn) LOSS: 0.019948 || (val) LOSS: 0.017592 | METRIC: -0.017592 || Runtime: 448
# EPOCH: 9 | LRs: {0.00010539538891265634}
# (trn) LOSS: 0.019382 || (val) LOSS: 0.017138 | METRIC: -0.017138 || Runtime: 449
# EPOCH: 10 | LRs: {7.631772324212795e-05}
# (trn) LOSS: 0.0186 || (val) LOSS: 0.016797 | METRIC: -0.016797 || Runtime: 450
# EPOCH: 11 | LRs: {5.0525493860872344e-05}
# (trn) LOSS: 0.018387 || (val) LOSS: 0.016825 | METRIC: -0.016825 || Runtime: 450
# EPOCH: 12 | LRs: {2.9168747158485322e-05}
# (trn) LOSS: 0.017754 || (val) LOSS: 0.01666 | METRIC: -0.01666 || Runtime: 448
# EPOCH: 13 | LRs: {1.3199756359415009e-05}
# (trn) LOSS: 0.017264 || (val) LOSS: 0.01652 | METRIC: -0.01652 || Runtime: 451
# EPOCH: 14 | LRs: {3.330560734966287e-06}
# (trn) LOSS: 0.017482 || (val) LOSS: 0.016501 | METRIC: -0.016501 || Runtime: 449
# Best Val Score: -0.016500877630270243
# Runtime: 6778

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v15/1024-b5-nodownconv \
--seed 0 \
--batch_size 16 \
--lr 3e-4 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 15 \
--encoder timm-efficientnet-b5 \
--in_channels 8 \
--encoder_depth 5 \
--resolution 1024 \
--dropout 0.2 \
--seg_pretrain 0 \
--annotated_weight 1.0 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 1.0 \
--val_freq 1 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--pretrained_path ../../model/v15/seg_pretrain/1024-b5-nodownconv/best.pth \
--use_attn 0 \
--k 128 \
--nheads 8 \
--focal 0 \
--downconv 0
# Out:
# Launched gpu 0
# Launched gpu 1
# Launched gpu 2
# Launched gpu 3
# # Train Samples: 24066 | # Val Samples: 6017
# # Parameters: 31666486
# <All keys matched successfully>
# Loaded Pretrained Weights from ../../model/v15/seg_pretrain/1024-b5-nodownconv/best.pth
# EPOCH: 0 | LRs: {1.200000000000002e-05}
# 100%|███████████████████████████████████████| 1505/1505 [18:08<00:00,  1.38it/s]
# 100%|█████████████████████████████████████████| 377/377 [02:13<00:00,  2.82it/s](trn) LOSS: 0.224558 ||
# (val) LOSS: 0.157245 | METRIC: 0.922574 || Runtime: 1254
# EPOCH: 1 | LRs: {0.00029757757403946325}
# (trn) LOSS: 0.174247 || (val) LOSS: 0.149064 | METRIC: 0.939877 || Runtime: 1239
# EPOCH: 2 | LRs: {0.00028864970824949614}

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v13/seg_pretrain/base_woattn \
--seed 0 \
--batch_size 64 \
--lr 2e-3 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 19 \
--encoder timm-efficientnet-b3 \
--in_channels 4 \
--encoder_depth 5 \
--resolution 768 \
--dropout 0.2 \
--seg_pretrain 1 \
--annotated_weight 0.9 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 0.2 \
--val_freq 2 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--use_attn 0 \
--k 64 \
--nheads 8 \
--focal 0
# Out:
# Launched gpu 0
# Launched gpu 1
# Launched gpu 2
# Launched gpu 3
# # Train Samples: 1483 | # Val Samples: 1895
# # Parameters: 13165927
# EPOCH: 0 | LRs: {7.999999999999999e-05}
# 100%|███████████████████████████████████████████| 24/24 [00:36<00:00,  1.52s/it]
# 100%|███████████████████████████████████████████| 30/30 [00:43<00:00,  1.43s/it](trn) LOSS: 0.420562 ||
# (val) LOSS: 0.17756 | METRIC: -0.17756 || Runtime: 109
# EPOCH: 1 | LRs: {0.0019899005589452986}
# (trn) LOSS: 0.102843 || (val) LOSS: None | METRIC: None || Runtime: 62
# EPOCH: 2 | LRs: {0.0019525592131964993}
# (trn) LOSS: 0.068724 || (val) LOSS: 0.067388 | METRIC: -0.067388 || Runtime: 106
# EPOCH: 3 | LRs: {0.0018887083065738813}
# (trn) LOSS: 0.057706 || (val) LOSS: None | METRIC: None || Runtime: 65
# EPOCH: 4 | LRs: {0.0018001248064096387}
# (trn) LOSS: 0.050263 || (val) LOSS: 0.04582 | METRIC: -0.04582 || Runtime: 107
# EPOCH: 5 | LRs: {0.001689273986797584}
# (trn) LOSS: 0.04466 || (val) LOSS: None | METRIC: None || Runtime: 65
# EPOCH: 6 | LRs: {0.0015592408201463583}
# (trn) LOSS: 0.041765 || (val) LOSS: 0.040518 | METRIC: -0.040518 || Runtime: 108
# EPOCH: 7 | LRs: {0.0014136441225615277}
# (trn) LOSS: 0.04049 || (val) LOSS: None | METRIC: None || Runtime: 62
# EPOCH: 8 | LRs: {0.001256535842386012}
# (trn) LOSS: 0.038244 || (val) LOSS: 0.036137 | METRIC: -0.036137 || Runtime: 112
# EPOCH: 9 | LRs: {0.0010922882946934108}
# (trn) LOSS: 0.036653 || (val) LOSS: None | METRIC: None || Runtime: 62
# EPOCH: 10 | LRs: {0.000925472479992262}
# (trn) LOSS: 0.035758 || (val) LOSS: 0.035999 | METRIC: -0.035999 || Runtime: 108
# EPOCH: 11 | LRs: {0.0007607308735252304}
# (trn) LOSS: 0.034221 || (val) LOSS: None | METRIC: None || Runtime: 64
# EPOCH: 12 | LRs: {0.0006026482254302454}
# (trn) LOSS: 0.032125 || (val) LOSS: 0.032958 | METRIC: -0.032958 || Runtime: 109
# EPOCH: 13 | LRs: {0.0004556239673882342}
# (trn) LOSS: 0.032156 || (val) LOSS: None | METRIC: None || Runtime: 64
# EPOCH: 14 | LRs: {0.00032374977667364436}
# (trn) LOSS: 0.031879 || (val) LOSS: 0.031859 | METRIC: -0.031859 || Runtime: 108
# EPOCH: 15 | LRs: {0.00021069570499371678}
# (trn) LOSS: 0.032865 || (val) LOSS: None | METRIC: None || Runtime: 65
# EPOCH: 16 | LRs: {0.00011960804114485244}
# (trn) LOSS: 0.031643 || (val) LOSS: 0.031045 | METRIC: -0.031045 || Runtime: 108
# EPOCH: 17 | LRs: {5.302174996289656e-05}
# (trn) LOSS: 0.031328 || (val) LOSS: None | METRIC: None || Runtime: 64
# EPOCH: 18 | LRs: {1.2789924386711295e-05}
# (trn) LOSS: 0.030557 || (val) LOSS: 0.031034 | METRIC: -0.031034 || Runtime: 107
# Best Val Score: -0.031033673048963026
# Runtime: 1666

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v14/supcon/base \
--seed 0 \
--batch_size 128 \
--lr 1e-3 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 23 \
--encoder timm-efficientnet-b3 \
--in_channels 4 \
--encoder_depth 5 \
--resolution 768 \
--dropout 0.2 \
--seg_pretrain 0 \
--annotated_weight 1.0 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 0.2 \
--val_freq 2 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--use_attn 0 \
--k 64 \
--nheads 8 \
--focal 0 \
--supcon 32
# Out:
# Launched gpu 0
# Launched gpu 1
# Launched gpu 2
# Launched gpu 3
# # Train Samples: 4813 | # Val Samples: 6017
# # Parameters: 13449287
# EPOCH: 0 | LRs: {3.9999999999999996e-05}
# 100%|███████████████████████████████████████████| 38/38 [00:52<00:00,  1.37s/it]
# 100%|███████████████████████████████████████████| 48/48 [00:59<00:00,  1.23s/it](trn) LOSS: 3.68823 ||
# (val) LOSS: 3.434001 | METRIC: -3.434001 || Runtime: 141
# EPOCH: 1 | LRs: {0.000996985288895229}
# (trn) LOSS: 3.429338 || (val) LOSS: None | METRIC: None || Runtime: 74
# EPOCH: 2 | LRs: {0.000984722468857606}
# (trn) LOSS: 3.427042 || (val) LOSS: 3.430324 | METRIC: -3.430324 || Runtime: 132
# EPOCH: 3 | LRs: {0.0009632471806192663}
# (trn) LOSS: 3.42543 || (val) LOSS: None | METRIC: None || Runtime: 73
# EPOCH: 4 | LRs: {0.0009329675777918437}
# (trn) LOSS: 3.424384 || (val) LOSS: 3.426536 | METRIC: -3.426536 || Runtime: 131
# EPOCH: 5 | LRs: {0.0008944591464463829}
# (trn) LOSS: 3.422606 || (val) LOSS: None | METRIC: None || Runtime: 73
# EPOCH: 6 | LRs: {0.0008484537675782661}
# (trn) LOSS: 3.419496 || (val) LOSS: 3.419317 | METRIC: -3.419317 || Runtime: 132
# EPOCH: 7 | LRs: {0.0007958258071718374}
# (trn) LOSS: 3.417193 || (val) LOSS: None | METRIC: None || Runtime: 74
# EPOCH: 8 | LRs: {0.0007375754982332567}
# (trn) LOSS: 3.415005 || (val) LOSS: 3.409533 | METRIC: -3.409533 || Runtime: 132
# EPOCH: 9 | LRs: {0.0006748099306282428}
# (trn) LOSS: 3.413755 || (val) LOSS: None | METRIC: None || Runtime: 75
# EPOCH: 10 | LRs: {0.0006087220100267873}
# (trn) LOSS: 3.412206 || (val) LOSS: 3.412091 | METRIC: -3.412091 || Runtime: 132
# EPOCH: 11 | LRs: {0.0005405677858555363}
# (trn) LOSS: 3.411714 || (val) LOSS: None | METRIC: None || Runtime: 74
# EPOCH: 12 | LRs: {0.00047164257915674316}
# (trn) LOSS: 3.4101 || (val) LOSS: 3.407113 | METRIC: -3.407113 || Runtime: 132
# EPOCH: 13 | LRs: {0.00040325636406134775}
# (trn) LOSS: 3.409505 || (val) LOSS: None | METRIC: None || Runtime: 73
# EPOCH: 14 | LRs: {0.00033670887076935264}
# (trn) LOSS: 3.407973 || (val) LOSS: 3.406163 | METRIC: -3.406163 || Runtime: 133
# EPOCH: 15 | LRs: {0.00027326488322362483}
# (trn) LOSS: 3.40659 || (val) LOSS: None | METRIC: None || Runtime: 73
# EPOCH: 16 | LRs: {0.00021413020096295628}
# (trn) LOSS: 3.407105 || (val) LOSS: 3.406589 | METRIC: -3.406589 || Runtime: 132
# EPOCH: 17 | LRs: {0.0001604287220170089}
# (trn) LOSS: 3.406536 || (val) LOSS: None | METRIC: None || Runtime: 74
# EPOCH: 18 | LRs: {0.00011318108239953942}
# (trn) LOSS: 3.405611 || (val) LOSS: 3.40595 | METRIC: -3.40595 || Runtime: 132
# EPOCH: 19 | LRs: {7.328525817200987e-05}
# (trn) LOSS: 3.40512 || (val) LOSS: None | METRIC: None || Runtime: 73
# EPOCH: 20 | LRs: {4.149949874960131e-05}
# (trn) LOSS: 3.404581 || (val) LOSS: 3.405539 | METRIC: -3.405539 || Runtime: 132
# EPOCH: 21 | LRs: {1.8427915814670913e-05}
# (trn) LOSS: 3.404223 || (val) LOSS: None | METRIC: None || Runtime: 73
# EPOCH: 22 | LRs: {4.50900173092914e-06}
# (trn) LOSS: 3.404556 || (val) LOSS: 3.405394 | METRIC: -3.405394 || Runtime: 135
# Best Val Score: -3.405393778297104
# Runtime: 2414

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v14/supcon-transfer \
--seed 0 \
--batch_size 64 \
--lr 2e-3 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 19 \
--encoder timm-efficientnet-b3 \
--in_channels 4 \
--encoder_depth 5 \
--resolution 768 \
--dropout 0.2 \
--seg_pretrain 0 \
--annotated_weight 1.0 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 0.2 \
--val_freq 2 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--use_attn 0 \
--k 64 \
--nheads 8 \
--focal 0 \
--supcon 0 \
--pretrained_path ../../model/v14/supcon/base/last.pth
# Out:
# Launched gpu 0
# Launched gpu 1
# Launched gpu 2
# Launched gpu 3
# # Train Samples: 4813 | # Val Samples: 6017
# # Parameters: 13449287
# <All keys matched successfully>
# Loaded Pretrained Weights from ../../model/v14/supcon/base/last.pth
# EPOCH: 0 | LRs: {7.999999999999999e-05}
# 100%|███████████████████████████████████████████| 76/76 [00:49<00:00,  1.55it/s]
# 100%|███████████████████████████████████████████| 95/95 [00:57<00:00,  1.66it/s](trn) LOSS: 0.297446 ||
# (val) LOSS: 0.245087 | METRIC: 0.765644 || Runtime: 136
# EPOCH: 1 | LRs: {0.001990564334131899}
# (trn) LOSS: 0.248349 || (val) LOSS: None | METRIC: None || Runtime: 75
# EPOCH: 2 | LRs: {0.001953997571199026}
# (trn) LOSS: 0.236954 || (val) LOSS: 0.230736 | METRIC: 0.805767 || Runtime: 132
# EPOCH: 3 | LRs: {0.0018908812179656955}
# (trn) LOSS: 0.231605 || (val) LOSS: None | METRIC: None || Runtime: 76
# EPOCH: 4 | LRs: {0.001802971799182381}
# (trn) LOSS: 0.227478 || (val) LOSS: 0.215019 | METRIC: 0.832511 || Runtime: 132
# EPOCH: 5 | LRs: {0.0016927158292939493}
# (trn) LOSS: 0.221868 || (val) LOSS: None | METRIC: None || Runtime: 76
# EPOCH: 6 | LRs: {0.0015631817260729002}
# (trn) LOSS: 0.215203 || (val) LOSS: 0.215507 | METRIC: 0.83925 || Runtime: 134
# EPOCH: 7 | LRs: {0.0014179744167161048}
# (trn) LOSS: 0.209569 || (val) LOSS: None | METRIC: None || Runtime: 77
# EPOCH: 8 | LRs: {0.0012611350129128273}
# (trn) LOSS: 0.202961 || (val) LOSS: 0.193642 | METRIC: 0.874798 || Runtime: 133
# EPOCH: 9 | LRs: {0.0010970283469215396}
# (trn) LOSS: 0.198463 || (val) LOSS: None | METRIC: None || Runtime: 76
# EPOCH: 10 | LRs: {0.0009302214985205331}
# (trn) LOSS: 0.191203 || (val) LOSS: 0.191137 | METRIC: 0.883208 || Runtime: 133
# EPOCH: 11 | LRs: {0.0007653566934208171}
# (trn) LOSS: 0.187041 || (val) LOSS: None | METRIC: None || Runtime: 76
# EPOCH: 12 | LRs: {0.0006070221103717103}
# (trn) LOSS: 0.179752 || (val) LOSS: 0.186702 | METRIC: 0.893748 || Runtime: 133
# EPOCH: 13 | LRs: {0.0004596241923905002}
# (trn) LOSS: 0.172829 || (val) LOSS: None | METRIC: None || Runtime: 76
# EPOCH: 14 | LRs: {0.0003272650156878509}
# (trn) LOSS: 0.169951 || (val) LOSS: 0.178391 | METRIC: 0.899613 || Runtime: 132
# EPOCH: 15 | LRs: {0.00021362812910523355}
# (trn) LOSS: 0.164384 || (val) LOSS: None | METRIC: None || Runtime: 76
# EPOCH: 16 | LRs: {0.00012187604114676333}
# (trn) LOSS: 0.16197 || (val) LOSS: 0.178225 | METRIC: 0.90059 || Runtime: 133
# EPOCH: 17 | LRs: {5.456220753588647e-05}
# (trn) LOSS: 0.160019 || (val) LOSS: None | METRIC: None || Runtime: 76
# EPOCH: 18 | LRs: {1.3559968678529727e-05}
# (trn) LOSS: 0.159567 || (val) LOSS: 0.178518 | METRIC: 0.900759 || Runtime: 132
# Best Val Score: 0.9007585804101137
# Runtime: 2023

# %% [markdown]
# # Process NIHCHEST

# %%
# !python process_nihchest.py \
--data_dir ../../input/nihchest \
--save_dir ../../input/processed/nihchest \
--num_workers 16 \
--compress 1 \
--model_dir ../../model/final_models \
--batch_size 96 \
--resolution 2048 \
--dataparallel 1
# Out:
# cuda
#
# best.pth
# {'logdir': '../../model/v14/2048-b5-in8', 'seed': 0, 'batch_size': 4, 'lr': 0.0003, 'raw_param_lr_ratio': 1.0, 'weight_decay': 0.01, 'epochs': 15, 'encoder': 'timm-efficientnet-b5', 'in_channels': 8, 'encoder_depth': 5, 'resolution': 2048, 'dropout': 0.2, 'annotated_weight': 1.0, 'seg_pos_weight': 100.0, 'num_workers': 16, 'fold': 0, 'data_frac': 1.0, 'amp': True, 'gpu_numbers': '0, 1, 2, 3', 'pretrained_path': '../../model/v14/seg_pretrain/2048-b5-in8/best.pth', 'data_dir': '../../input/processed/data', 'df_dir': '../../input/kaggle/', 'val_freq': 1, 'init_random': True, 'use_attn': 0, 'k': 128, 'nheads': 8, 'focal': 0.0, 'aug': 1, 'seg_pretrain': 0, 'supcon': 0, 'downconv': 1}
# <All keys matched successfully>
# 0.9622116466780354
#
# # uids: 112120
# 100%|███████████████████████████████████████| 1168/1168 [35:13<00:00,  1.81s/it]
# 100%|██████████████████████████████████| 112120/112120 [03:08<00:00, 594.75it/s]

# %% [markdown]
# # Pseudo Train

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v15/pseudo-1024-b5 \
--seed 0 \
--batch_size 64 \
--lr 8e-4 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 10 \
--encoder timm-efficientnet-b5 \
--in_channels 8 \
--encoder_depth 5 \
--resolution 1024 \
--dropout 0.2 \
--seg_pretrain 0 \
--annotated_weight 1.0 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 1.0 \
--val_freq 1 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--use_attn 0 \
--k 128 \
--nheads 8 \
--focal 0 \
--pseudo_data_dir ../../input/processed/nihchest
# Out:
# Launched gpu 0
# Launched gpu 1
# Launched gpu 2
# Launched gpu 3
# # Train Samples: 136186 | # Val Samples: 6017
# # Parameters: 31669699
# EPOCH: 0 | LRs: {3.200000000000002e-05}
# 100%|███████████████████████████████████████| 2128/2128 [32:10<00:00,  1.10it/s]
# 100%|███████████████████████████████████████████| 95/95 [01:13<00:00,  1.30it/s](trn) LOSS: 0.180524 ||
# (val) LOSS: 0.160185 | METRIC: 0.926789 || Runtime: 2033
# EPOCH: 1 | LRs: {0.00078378044499641}
# (trn) LOSS: 0.144647 || (val) LOSS: 0.143234 | METRIC: 0.945916 || Runtime: 2034
# EPOCH: 2 | LRs: {0.0007294370866171763}
# (trn) LOSS: 0.137445 || (val) LOSS: 0.139219 | METRIC: 0.948011 || Runtime: 2063
# EPOCH: 3 | LRs: {0.0006421970369914156}
# (trn) LOSS: 0.132288 || (val) LOSS: 0.135812 | METRIC: 0.952862 || Runtime: 2055
# EPOCH: 4 | LRs: {0.0005307718924512057}
# (trn) LOSS: 0.128198 || (val) LOSS: 0.131572 | METRIC: 0.955488 || Runtime: 2103
# EPOCH: 5 | LRs: {0.0004062883188414389}
# (trn) LOSS: 0.124269 || (val) LOSS: 0.128921 | METRIC: 0.958116 || Runtime: 2006
# EPOCH: 6 | LRs: {0.00028117696754201217}
# (trn) LOSS: 0.12098 || (val) LOSS: 0.12856 | METRIC: 0.958013 || Runtime: 2212
# EPOCH: 7 | LRs: {0.0001679311784095262}
# (trn) LOSS: 0.118138 || (val) LOSS: 0.127852 | METRIC: 0.9592 || Runtime: 2156
# EPOCH: 8 | LRs: {7.785942278783995e-05}
# (trn) LOSS: 0.116054 || (val) LOSS: 0.12779 | METRIC: 0.959585 || Runtime: 2105
# EPOCH: 9 | LRs: {1.9956064839556697e-05}
# (trn) LOSS: 0.115152 || (val) LOSS: 0.12849 | METRIC: 0.959412 || Runtime: 2192
# Best Val Score: 0.9595853976005493
# Runtime: 20963

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v15/pseudo-2048-b5 \
--seed 0 \
--batch_size 16 \
--lr 3e-4 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 8 \
--encoder timm-efficientnet-b5 \
--in_channels 8 \
--encoder_depth 5 \
--resolution 2048 \
--dropout 0.2 \
--seg_pretrain 0 \
--annotated_weight 1.0 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 1.0 \
--val_freq 1 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--use_attn 0 \
--k 128 \
--nheads 8 \
--focal 0 \
--pseudo_data_dir ../../input/processed/nihchest
# Out:
# Launched gpu 1
# Launched gpu 3
# Launched gpu 0
# Launched gpu 2
# # Train Samples: 136186 | # Val Samples: 6017
# # Parameters: 31669699
# EPOCH: 0 | LRs: {1.200000000000002e-05}
# 100%|█████████████████████████████████████| 8512/8512 [2:05:21<00:00,  1.13it/s]
# 100%|█████████████████████████████████████████| 377/377 [02:27<00:00,  2.56it/s](trn) LOSS: 0.161623 ||
# (val) LOSS: 0.149176 | METRIC: 0.940389 || Runtime: 7699
# EPOCH: 1 | LRs: {0.00029011972373306917}
# (trn) LOSS: 0.127209 || (val) LOSS: 0.13232 | METRIC: 0.955659 || Runtime: 7680
# EPOCH: 2 | LRs: {0.00025855544764494834}
# (trn) LOSS: 0.119273 || (val) LOSS: 0.128154 | METRIC: 0.959948 || Runtime: 7686
# EPOCH: 3 | LRs: {0.0002101335360093043}
# (trn) LOSS: 0.113525 || (val) LOSS: 0.123375 | METRIC: 0.963048 || Runtime: 7685
# EPOCH: 4 | LRs: {0.00015237349584564726}
# (trn) LOSS: 0.108827 || (val) LOSS: 0.122069 | METRIC: 0.964407 || Runtime: 7697
# EPOCH: 5 | LRs: {9.424496533608708e-05}
# (trn) LOSS: 0.104642 || (val) LOSS: 0.124021 | METRIC: 0.964845 || Runtime: 7679
# EPOCH: 6 | LRs: {4.477480604878009e-05}
# (trn) LOSS: 0.101606 || (val) LOSS: 0.123835 | METRIC: 0.96443 || Runtime: 7698
# EPOCH: 7 | LRs: {1.1645308860969723e-05}
# (trn) LOSS: 0.099954 || (val) LOSS: 0.124749 | METRIC: 0.964309 || Runtime: 7705
# Best Val Score: 0.9648447614934997
# Runtime: 61533

# %% [markdown]
# # 2048 FineTune

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v15/2048-b5-pseudoft \
--seed 0 \
--batch_size 16 \
--lr 1e-4 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 3 \
--encoder timm-efficientnet-b5 \
--in_channels 8 \
--encoder_depth 5 \
--resolution 2048 \
--dropout 0.2 \
--seg_pretrain 0 \
--annotated_weight 1.0 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 1.0 \
--val_freq 1 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--pretrained_path ../../model/v15/pseudo-1024-b5/best.pth \
--use_attn 0 \
--k 128 \
--nheads 8 \
--focal 0
# Out:
# Launched gpu 0
# Launched gpu 1
# Launched gpu 2
# Launched gpu 3
# # Train Samples: 24066 | # Val Samples: 6017
# # Parameters: 31669699
# <All keys matched successfully>
# Loaded Pretrained Weights from ../../model/v15/pseudo-1024-b5/best.pth
# EPOCH: 0 | LRs: {4.000000000000002e-06}
# 100%|███████████████████████████████████████| 1505/1505 [22:33<00:00,  1.11it/s]
# 100%|█████████████████████████████████████████| 377/377 [02:27<00:00,  2.56it/s](trn) LOSS: 0.142182 ||
# (val) LOSS: 0.127569 | METRIC: 0.957861 || Runtime: 1532
# EPOCH: 1 | LRs: {7.58804324120573e-05}
# (trn) LOSS: 0.12181 || (val) LOSS: 0.128484 | METRIC: 0.959232 || Runtime: 1517
# EPOCH: 2 | LRs: {2.542910649510349e-05}
# (trn) LOSS: 0.117169 || (val) LOSS: 0.128341 | METRIC: 0.959545 || Runtime: 1517
# Best Val Score: 0.9595446009913602
# Runtime: 4567

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v15/2048-b5-pseudoft-lr3e-5-epoch5 \
--seed 0 \
--batch_size 16 \
--lr 3e-5 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 5 \
--encoder timm-efficientnet-b5 \
--in_channels 8 \
--encoder_depth 5 \
--resolution 2048 \
--dropout 0.2 \
--seg_pretrain 0 \
--annotated_weight 1.0 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 1.0 \
--val_freq 1 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--pretrained_path ../../model/v15/pseudo-1024-b5/best.pth \
--use_attn 0 \
--k 128 \
--nheads 8 \
--focal 0
# Out:
# Launched gpu 0
# Launched gpu 1
# Launched gpu 2
# Launched gpu 3
# # Train Samples: 24066 | # Val Samples: 6017
# # Parameters: 31669699
# <All keys matched successfully>
# Loaded Pretrained Weights from ../../model/v15/pseudo-1024-b5/best.pth
# EPOCH: 0 | LRs: {1.1999999999999987e-06}
# 100%|███████████████████████████████████████| 1505/1505 [22:42<00:00,  1.10it/s]
# 100%|█████████████████████████████████████████| 377/377 [02:27<00:00,  2.55it/s](trn) LOSS: 0.159279 ||
# (val) LOSS: 0.131393 | METRIC: 0.95397 || Runtime: 1541
# EPOCH: 1 | LRs: {2.735157124178756e-05}
# (trn) LOSS: 0.131773 || (val) LOSS: 0.129311 | METRIC: 0.957005 || Runtime: 1519
# EPOCH: 2 | LRs: {1.9900081747923957e-05}
# (trn) LOSS: 0.12703 || (val) LOSS: 0.128537 | METRIC: 0.957866 || Runtime: 1519
# EPOCH: 3 | LRs: {1.0540232307929467e-05}
# (trn) LOSS: 0.124294 || (val) LOSS: 0.128582 | METRIC: 0.957994 || Runtime: 1518
# EPOCH: 4 | LRs: {2.9173050638004705e-06}
# Traceback (most recent call last):
# ^C
#   File "<string>", line 1, in <module>
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/multiprocessing/spawn.py", line 125, in _main
#     prepare(preparation_data)
# Traceback (most recent call last):
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/multiprocessing/spawn.py", line 236, in prepare
#   File "train.py", line 301, in <module>
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/multiprocessing/spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/runpy.py", line 265, in run_path
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fb3c5f11af0>
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fd408d56af0>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     return _run_module_code(code, init_globals, run_name,
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/runpy.py", line 87, in _run_code
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7ff4d8e2eaf0>
# Traceback (most recent call last):
#
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/torch/multiprocessing/spawn.py", line 199, in spawn
#     exec(code, run_globals)
#   File "/home/vnfmadl97/kaggle/ranzcr-clip-catheter-line-classification/code/v15/train.py", line 13, in <module>
#     from data import get_loader
#   File "/home/vnfmadl97/kaggle/ranzcr-clip-catheter-line-classification/code/v15/data.py", line 7, in <module>
#     return start_processes(fn, args, nprocs, join, daemon, start_method='spawn')
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/torch/multiprocessing/spawn.py", line 157, in start_processes
#     while not context.join():
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/torch/multiprocessing/spawn.py", line 75, in join
#     ready = multiprocessing.connection.wait(
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt
#     import albumentations as albu
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/albumentations/__init__.py", line 5, in <module>
#     from .core.composition import *
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/albumentations/core/composition.py", line 8, in <module>
#     self._shutdown_workers()
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1174, in _shutdown_workers
#     self._shutdown_workers()
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1174, in _shutdown_workers
#     from albumentations.augmentations.keypoints_utils import KeypointsProcessor
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/albumentations/augmentations/__init__.py", line 5, in <module>
#     self._shutdown_workers()
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1174, in _shutdown_workers
#     if self._persistent_workers or self._workers_status[worker_id]:
#     from .transforms import *
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/albumentations/augmentations/transforms.py", line 13, in <module>
# AttributeError: '_MultiProcessingDataLoaderIter' object has no attribute '_workers_status'
#     if self._persistent_workers or self._workers_status[worker_id]:
# AttributeError: '_MultiProcessingDataLoaderIter' object has no attribute '_workers_status'
#     from skimage.measure import label
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/skimage/measure/__init__.py", line 8, in <module>
#     if self._persistent_workers or self._workers_status[worker_id]:
#     from ._polygon import approximate_polygon, subdivide_polygon
# AttributeError: '_MultiProcessingDataLoaderIter' object has no attribute '_workers_status'
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/skimage/measure/_polygon.py", line 2, in <module>
#     from scipy import signal
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/scipy/signal/__init__.py", line 305, in <module>
#     from .spectral import *
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 779, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 911, in get_code
#   File "<frozen importlib._bootstrap_external>", line 580, in _compile_bytecode
# KeyboardInterrupt
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f3f7e511af0>
# Traceback (most recent call last):
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1174, in _shutdown_workers
#     if self._persistent_workers or self._workers_status[worker_id]:
# AttributeError: '_MultiProcessingDataLoaderIter' object has no attribute '_workers_status'
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/multiprocessing/spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/multiprocessing/spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/multiprocessing/spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/runpy.py", line 265, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/vnfmadl97/kaggle/ranzcr-clip-catheter-line-classification/code/v15/train.py", line 12, in <module>
#     from model import RANZCRModel, seg_loss, cls_loss, supcon_loss, kaggle_metric
#   File "/home/vnfmadl97/kaggle/ranzcr-clip-catheter-line-classification/code/v15/model.py", line 4, in <module>
#     import segmentation_models_pytorch as smp
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/segmentation_models_pytorch/__init__.py", line 1, in <module>
#     from .unet import Unet
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/segmentation_models_pytorch/unet/__init__.py", line 1, in <module>
#     from .model import Unet
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/segmentation_models_pytorch/unet/model.py", line 3, in <module>
#     from ..encoders import get_encoder
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/segmentation_models_pytorch/encoders/__init__.py", line 4, in <module>
#     from .resnet import resnet_encoders
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/segmentation_models_pytorch/encoders/resnet.py", line 32, in <module>
#     from pretrainedmodels.models.torchvision_models import pretrained_settings
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/pretrainedmodels/__init__.py", line 3, in <module>
#     from . import models
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/pretrainedmodels/models/__init__.py", line 8, in <module>
#     from .resnext import resnext101_32x4d
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/pretrainedmodels/models/resnext.py", line 6, in <module>
#     from .resnext_features import resnext101_32x4d_features
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/pretrainedmodels/models/resnext_features/__init__.py", line 3, in <module>
#     from .resnext101_64x4d_features import resnext101_64x4d_features
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/pretrainedmodels/models/resnext_features/resnext101_64x4d_features.py", line 666, in <module>
#     nn.Conv2d(2048, 2048, (1, 1), (1, 1), (0, 0), 1, 1, bias = False),
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/torch/nn/modules/conv.py", line 410, in __init__
#     super(Conv2d, self).__init__(
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/torch/nn/modules/conv.py", line 83, in __init__
#     self.reset_parameters()
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/torch/nn/modules/conv.py", line 86, in reset_parameters
#     init.kaiming_uniform_(self.weight, a=math.sqrt(5))
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/torch/nn/init.py", line 384, in kaiming_uniform_
#     return tensor.uniform_(-bound, bound)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/multiprocessing/spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/multiprocessing/spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/multiprocessing/spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/runpy.py", line 265, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/vnfmadl97/kaggle/ranzcr-clip-catheter-line-classification/code/v15/train.py", line 12, in <module>
#     from model import RANZCRModel, seg_loss, cls_loss, supcon_loss, kaggle_metric
#   File "/home/vnfmadl97/kaggle/ranzcr-clip-catheter-line-classification/code/v15/model.py", line 4, in <module>
#     import segmentation_models_pytorch as smp
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/segmentation_models_pytorch/__init__.py", line 1, in <module>
#     from .unet import Unet
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/segmentation_models_pytorch/unet/__init__.py", line 1, in <module>
#     from .model import Unet
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/segmentation_models_pytorch/unet/model.py", line 3, in <module>
#     from ..encoders import get_encoder
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/segmentation_models_pytorch/encoders/__init__.py", line 4, in <module>
#     from .resnet import resnet_encoders
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/segmentation_models_pytorch/encoders/resnet.py", line 32, in <module>
#     from pretrainedmodels.models.torchvision_models import pretrained_settings
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/pretrainedmodels/__init__.py", line 3, in <module>
#     from . import models
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/pretrainedmodels/models/__init__.py", line 8, in <module>
#     from .resnext import resnext101_32x4d
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/pretrainedmodels/models/resnext.py", line 6, in <module>
#     from .resnext_features import resnext101_32x4d_features
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/pretrainedmodels/models/resnext_features/__init__.py", line 3, in <module>
#     from .resnext101_64x4d_features import resnext101_64x4d_features
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/pretrainedmodels/models/resnext_features/resnext101_64x4d_features.py", line 673, in <module>
#     nn.Conv2d(2048, 2048, (1, 1), (1, 1), (0, 0), 1, 1, bias = False),
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/torch/nn/modules/conv.py", line 410, in __init__
#     super(Conv2d, self).__init__(
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/torch/nn/modules/conv.py", line 83, in __init__
#     self.reset_parameters()
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/torch/nn/modules/conv.py", line 86, in reset_parameters
#     init.kaiming_uniform_(self.weight, a=math.sqrt(5))
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/torch/nn/init.py", line 384, in kaiming_uniform_
#     return tensor.uniform_(-bound, bound)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/multiprocessing/spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/multiprocessing/spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/multiprocessing/spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/runpy.py", line 265, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/vnfmadl97/kaggle/ranzcr-clip-catheter-line-classification/code/v15/train.py", line 13, in <module>
#     from data import get_loader
#   File "/home/vnfmadl97/kaggle/ranzcr-clip-catheter-line-classification/code/v15/data.py", line 7, in <module>
#     import albumentations as albu
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/albumentations/__init__.py", line 9, in <module>
#     from .imgaug.transforms import *
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/albumentations/imgaug/transforms.py", line 1, in <module>
#     import imgaug as ia
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/imgaug/__init__.py", line 7, in <module>
#     from imgaug.imgaug import *  # pylint: disable=redefined-builtin
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/imgaug/imgaug.py", line 19, in <module>
#     import imageio
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/imageio/__init__.py", line 38, in <module>
#     from . import plugins
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/imageio/plugins/__init__.py", line 92, in <module>
#     from . import bsdf
#   File "/home/vnfmadl97/anaconda3/envs/gpu/lib/python3.8/site-packages/imageio/plugins/bsdf.py", line 87, in <module>
#     class BsdfFormat(Format):
# KeyboardInterrupt

# %% [markdown]
# # Infer

# %%
# !python infer.py \
--data_dir ../../input/kaggle/train \
--model_dir ../../model/final_models \
--out_dir . \
--batch_size 16 \
--num_workers 32 \
--resolution 2048 \
--fold 0 \
--folds_path folds.jl \
--train_df_path ../../input/kaggle/train.csv
# Out:
# cuda
#
# best.pth
# {'logdir': '../../model/v14/2048-b5-in8', 'seed': 0, 'batch_size': 4, 'lr': 0.0003, 'raw_param_lr_ratio': 1.0, 'weight_decay': 0.01, 'epochs': 15, 'encoder': 'timm-efficientnet-b5', 'in_channels': 8, 'encoder_depth': 5, 'resolution': 2048, 'dropout': 0.2, 'annotated_weight': 1.0, 'seg_pos_weight': 100.0, 'num_workers': 16, 'fold': 0, 'data_frac': 1.0, 'amp': True, 'gpu_numbers': '0, 1, 2, 3', 'pretrained_path': '../../model/v14/seg_pretrain/2048-b5-in8/best.pth', 'data_dir': '../../input/processed/data', 'df_dir': '../../input/kaggle/', 'val_freq': 1, 'init_random': True, 'use_attn': 0, 'k': 128, 'nheads': 8, 'focal': 0.0, 'aug': 1, 'seg_pretrain': 0, 'supcon': 0}
# <All keys matched successfully>
# 0.9622116466780354
#
# # uids: 6017
# 100%|█████████████████████████████████████████| 377/377 [04:14<00:00,  1.48it/s]
# Fold0 SCORE 0.9622073769100872
