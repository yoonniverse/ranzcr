# %% [markdown]
# # PREPROCESS

# %%
# !python preprocess.py \
--data_dir ../../input/kaggle \
--save_dir ../../input/processed/data \
--njobs 24 \
--nfolds 5 \
--compress 1
# Out:
# 100%|████████████████████████████████████| 30083/30083 [02:38<00:00, 190.04it/s]

# %% [markdown]
# # TRAIN

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v15/seg_pretrain/2048-eff7 \
--seed 0 \
--batch_size 8 \
--lr 2e-4 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 15 \
--encoder timm-efficientnet-b7 \
--in_channels 8 \
--encoder_depth 5 \
--resolution 2048 \
--dropout 0.2 \
--seg_pretrain 1 \
--supcon 0 \
--annotated_weight 1.0 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 1.0 \
--val_freq 1 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--use_attn 0 \
--k 128 \
--nheads 8 \
--focal 0 \
--aug 1 \
--downconv 1
# Out:
# Launched gpu 0
# Launched gpu 2
# Launched gpu 3
# Launched gpu 1
# # Train Samples: 7200 | # Val Samples: 1895
# # Parameters: 67744051
# EPOCH: 0 | LRs: {8.000000000000005e-06}
# ...
# 100%|█████████████████████████████████████████| 237/237 [01:20<00:00,  2.95it/s](trn) LOSS: 0.183468 ||
# (val) LOSS: 0.036088 | METRIC: -0.036088 || Runtime: 1104
# EPOCH: 1 | LRs: {0.0001983833575722894}
# (trn) LOSS: 0.032912 || (val) LOSS: 0.024985 | METRIC: -0.024985 || Runtime: 1119
# EPOCH: 2 | LRs: {0.00019242953266133822}
# (trn) LOSS: 0.026227 || (val) LOSS: 0.0211 | METRIC: -0.0211 || Runtime: 1119
# EPOCH: 3 | LRs: {0.0001823543970742383}
# (trn) LOSS: 0.023217 || (val) LOSS: 0.019595 | METRIC: -0.019595 || Runtime: 1133
# EPOCH: 4 | LRs: {0.00016860718973234695}
# (trn) LOSS: 0.0225 || (val) LOSS: 0.018746 | METRIC: -0.018746 || Runtime: 1103
# EPOCH: 5 | LRs: {0.0001518008830909283}
# (trn) LOSS: 0.021014 || (val) LOSS: 0.018178 | METRIC: -0.018178 || Runtime: 1100
# ...

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v15/2048-eff7 \
--seed 0 \
--batch_size 8 \
--lr 2e-4 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 15 \
--encoder timm-efficientnet-b7 \
--in_channels 8 \
--encoder_depth 5 \
--resolution 2048 \
--dropout 0.2 \
--seg_pretrain 0 \
--supcon 0 \
--annotated_weight 1.0 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 1.0 \
--val_freq 1 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--use_attn 0 \
--k 128 \
--nheads 8 \
--focal 0 \
--aug 1 \
--downconv 1 \
--pretrained_path ../../model/v15/seg_pretrain/2048-eff7/best.pth
# Out:
# Launched gpu 0
# Launched gpu 1
# Launched gpu 2
# Launched gpu 3
# # Train Samples: 24066 | # Val Samples: 6017
# # Parameters: 67744051
# <All keys matched successfully>
# Loaded Pretrained Weights from ../../model/v15/seg_pretrain/2048-eff7/best.pth
# EPOCH: 0 | LRs: {8.000000000000005e-06}
# ...
# 100%|█████████████████████████████████████████| 753/753 [02:47<00:00,  4.50it/s](trn) LOSS: 0.222663 ||
# (val) LOSS: 0.159516 | METRIC: 0.924222 || Runtime: 2528
# EPOCH: 1 | LRs: {0.00019838630672623918}
# (trn) LOSS: 0.172226 || (val) LOSS: 0.145078 | METRIC: 0.945878 || Runtime: 2512
# EPOCH: 2 | LRs: {0.00019243581968303455}
# (trn) LOSS: 0.160803 || (val) LOSS: 0.142162 | METRIC: 0.949088 || Runtime: 2517
# EPOCH: 3 | LRs: {0.00018236374163248158}
# (trn) LOSS: 0.151186 || (val) LOSS: 0.133654 | METRIC: 0.953211 || Runtime: 2510
# EPOCH: 4 | LRs: {0.00016861917516383475}
# (trn) LOSS: 0.14421 || (val) LOSS: 0.128179 | METRIC: 0.956928 || Runtime: 2511
# ...

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v15/2048-regnety120 \
--seed 0 \
--batch_size 16 \
--lr 3e-4 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 15 \
--encoder timm-regnety_120 \
--in_channels 8 \
--encoder_depth 5 \
--resolution 2048 \
--dropout 0.2 \
--seg_pretrain 0 \
--supcon 0 \
--annotated_weight 1.0 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 1.0 \
--val_freq 1 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--use_attn 0 \
--k 128 \
--nheads 8 \
--focal 0 \
--aug 1 \
--downconv 1
# Out:
# Launched gpu 0
# Launched gpu 2
# Launched gpu 1
# Launched gpu 3
# # Train Samples: 24066 | # Val Samples: 6017
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-regnet/regnety_120-721ba79a.pth" to /home/vnfmadl97/.cache/torch/hub/checkpoints/regnety_120-721ba79a.pth
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-regnet/regnety_120-721ba79a.pth" to /home/vnfmadl97/.cache/torch/hub/checkpoints/regnety_120-721ba79a.pth
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-regnet/regnety_120-721ba79a.pth" to /home/vnfmadl97/.cache/torch/hub/checkpoints/regnety_120-721ba79a.pth
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-regnet/regnety_120-721ba79a.pth" to /home/vnfmadl97/.cache/torch/hub/checkpoints/regnety_120-721ba79a.pth
# 100%|████████████████████████████████████████| 198M/198M [00:10<00:00, 19.3MB/s]
# ...

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v13/seg_pretrain/base_woattn \
--seed 0 \
--batch_size 64 \
--lr 2e-3 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 19 \
--encoder timm-efficientnet-b3 \
--in_channels 4 \
--encoder_depth 5 \
--resolution 768 \
--dropout 0.2 \
--seg_pretrain 1 \
--annotated_weight 0.9 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 0.2 \
--val_freq 2 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--use_attn 0 \
--k 64 \
--nheads 8 \
--focal 0
# Out:
# Launched gpu 0
# Launched gpu 1
# Launched gpu 2
# Launched gpu 3
# # Train Samples: 1483 | # Val Samples: 1895
# # Parameters: 13165927
# EPOCH: 0 | LRs: {7.999999999999999e-05}
# ...
# 100%|███████████████████████████████████████████| 30/30 [00:43<00:00,  1.43s/it](trn) LOSS: 0.420562 ||
# (val) LOSS: 0.17756 | METRIC: -0.17756 || Runtime: 109
# EPOCH: 1 | LRs: {0.0019899005589452986}
# (trn) LOSS: 0.102843 || (val) LOSS: None | METRIC: None || Runtime: 62
# EPOCH: 2 | LRs: {0.0019525592131964993}
# (trn) LOSS: 0.068724 || (val) LOSS: 0.067388 | METRIC: -0.067388 || Runtime: 106
# EPOCH: 3 | LRs: {0.0018887083065738813}
# (trn) LOSS: 0.057706 || (val) LOSS: None | METRIC: None || Runtime: 65
# EPOCH: 4 | LRs: {0.0018001248064096387}
# (trn) LOSS: 0.050263 || (val) LOSS: 0.04582 | METRIC: -0.04582 || Runtime: 107
# EPOCH: 5 | LRs: {0.001689273986797584}
# (trn) LOSS: 0.04466 || (val) LOSS: None | METRIC: None || Runtime: 65
# EPOCH: 6 | LRs: {0.0015592408201463583}
# ...

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v14/supcon/base \
--seed 0 \
--batch_size 128 \
--lr 1e-3 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 23 \
--encoder timm-efficientnet-b3 \
--in_channels 4 \
--encoder_depth 5 \
--resolution 768 \
--dropout 0.2 \
--seg_pretrain 0 \
--annotated_weight 1.0 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 0.2 \
--val_freq 2 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--use_attn 0 \
--k 64 \
--nheads 8 \
--focal 0 \
--supcon 32
# Out:
# Launched gpu 0
# Launched gpu 1
# Launched gpu 2
# Launched gpu 3
# # Train Samples: 4813 | # Val Samples: 6017
# # Parameters: 13449287
# EPOCH: 0 | LRs: {3.9999999999999996e-05}
# ...
# 100%|███████████████████████████████████████████| 48/48 [00:59<00:00,  1.23s/it](trn) LOSS: 3.68823 ||
# (val) LOSS: 3.434001 | METRIC: -3.434001 || Runtime: 141
# EPOCH: 1 | LRs: {0.000996985288895229}
# (trn) LOSS: 3.429338 || (val) LOSS: None | METRIC: None || Runtime: 74
# EPOCH: 2 | LRs: {0.000984722468857606}
# (trn) LOSS: 3.427042 || (val) LOSS: 3.430324 | METRIC: -3.430324 || Runtime: 132
# EPOCH: 3 | LRs: {0.0009632471806192663}
# (trn) LOSS: 3.42543 || (val) LOSS: None | METRIC: None || Runtime: 73
# EPOCH: 4 | LRs: {0.0009329675777918437}
# (trn) LOSS: 3.424384 || (val) LOSS: 3.426536 | METRIC: -3.426536 || Runtime: 131
# EPOCH: 5 | LRs: {0.0008944591464463829}
# (trn) LOSS: 3.422606 || (val) LOSS: None | METRIC: None || Runtime: 73
# EPOCH: 6 | LRs: {0.0008484537675782661}
# ...

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v14/supcon-transfer \
--seed 0 \
--batch_size 64 \
--lr 2e-3 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 19 \
--encoder timm-efficientnet-b3 \
--in_channels 4 \
--encoder_depth 5 \
--resolution 768 \
--dropout 0.2 \
--seg_pretrain 0 \
--annotated_weight 1.0 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 0.2 \
--val_freq 2 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--use_attn 0 \
--k 64 \
--nheads 8 \
--focal 0 \
--supcon 0 \
--pretrained_path ../../model/v14/supcon/base/last.pth
# Out:
# Launched gpu 0
# Launched gpu 1
# Launched gpu 2
# Launched gpu 3
# # Train Samples: 4813 | # Val Samples: 6017
# # Parameters: 13449287
# <All keys matched successfully>
# Loaded Pretrained Weights from ../../model/v14/supcon/base/last.pth
# EPOCH: 0 | LRs: {7.999999999999999e-05}
# ...
# 100%|███████████████████████████████████████████| 95/95 [00:57<00:00,  1.66it/s](trn) LOSS: 0.297446 ||
# (val) LOSS: 0.245087 | METRIC: 0.765644 || Runtime: 136
# EPOCH: 1 | LRs: {0.001990564334131899}
# (trn) LOSS: 0.248349 || (val) LOSS: None | METRIC: None || Runtime: 75
# EPOCH: 2 | LRs: {0.001953997571199026}
# (trn) LOSS: 0.236954 || (val) LOSS: 0.230736 | METRIC: 0.805767 || Runtime: 132
# EPOCH: 3 | LRs: {0.0018908812179656955}
# (trn) LOSS: 0.231605 || (val) LOSS: None | METRIC: None || Runtime: 76
# EPOCH: 4 | LRs: {0.001802971799182381}
# (trn) LOSS: 0.227478 || (val) LOSS: 0.215019 | METRIC: 0.832511 || Runtime: 132
# EPOCH: 5 | LRs: {0.0016927158292939493}
# ...

# %% [markdown]
# # Pseudo Label NIHCHEST and TEST

# %%
# !python pseudo_label.py \
--data_dir ../../input/nihchest \
--save_dir ../../input/processed/nihchest \
--num_workers 16 \
--compress 1 \
--model_dir ../../model/final_models \
--batch_size 96 \
--resolution 2048 \
--dataparallel 1 \
--weights 0.8-0.2
# Out:
# cuda
#
# 2048-b5-pseudo.pth
# {'logdir': '../../model/v15/pseudo-2048-b5', 'seed': 0, 'batch_size': 4, 'lr': 0.0003, 'raw_param_lr_ratio': 1.0, 'weight_decay': 0.01, 'epochs': 8, 'encoder': 'timm-efficientnet-b5', 'in_channels': 8, 'encoder_depth': 5, 'resolution': 2048, 'dropout': 0.2, 'annotated_weight': 1.0, 'seg_pos_weight': 100.0, 'num_workers': 16, 'fold': 0, 'data_frac': 1.0, 'amp': True, 'gpu_numbers': '0, 1, 2, 3', 'pretrained_path': None, 'data_dir': '../../input/processed/data', 'df_dir': '../../input/kaggle/', 'val_freq': 1, 'init_random': True, 'use_attn': 0, 'k': 128, 'nheads': 8, 'focal': 0.0, 'aug': 1, 'seg_pretrain': 0, 'supcon': 0, 'pseudo_data_dir': '../../input/processed/nihchest', 'downconv': 1}
# <All keys matched successfully>
# 0.9648447614934997
#
#
# 2048-b7.pth
# ...

# %% [markdown]
# # Pseudo Train

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v15/0.967pseudo-2048-b5 \
--seed 0 \
--batch_size 16 \
--lr 3e-4 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 7 \
--encoder timm-efficientnet-b5 \
--in_channels 8 \
--encoder_depth 5 \
--resolution 2048 \
--dropout 0.2 \
--seg_pretrain 0 \
--annotated_weight 1.0 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 1.0 \
--val_freq 1 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--use_attn 0 \
--k 128 \
--nheads 8 \
--focal 0 \
--pseudo_data_dir ../../input/processed/nihchest \
--resume 1
# Out:
# Launched gpu 0
# Launched gpu 1
# Launched gpu 2
# Launched gpu 3
# # Train Samples: 139768 | # Val Samples: 6017
# # Parameters: 31669699
# Resume from ../../model/v15/0.967pseudo-2048-b5/last.pth. Best val metric: 0.9437596979699034
# EPOCH: 1 | LRs: {0.00028686223083743313}
# (trn) LOSS: 0.122541 || (val) LOSS: 0.134443 | METRIC: 0.957176 || Runtime: 7908
# EPOCH: 2 | LRs: {0.0002461516806410169}
# (trn) LOSS: 0.114199 || (val) LOSS: 0.131001 | METRIC: 0.959811 || Runtime: 7912
# EPOCH: 3 | LRs: {0.0001860172048350566}
# (trn) LOSS: 0.108182 || (val) LOSS: 0.12473 | METRIC: 0.963548 || Runtime: 7968
# EPOCH: 4 | LRs: {0.00011860684769359251}
# (trn) LOSS: 0.103516 || (val) LOSS: 0.124356 | METRIC: 0.965273 || Runtime: 7941
# EPOCH: 5 | LRs: {5.753848801423483e-05}
# (trn) LOSS: 0.099512 || (val) LOSS: 0.123558 | METRIC: 0.965525 || Runtime: 7950
# EPOCH: 6 | LRs: {1.5148828282287793e-05}
# (trn) LOSS: 0.097819 || (val) LOSS: 0.123761 | METRIC: 0.965911 || Runtime: 7943
# ...

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v15/pseudo-2048-b5 \
--seed 0 \
--batch_size 16 \
--lr 3e-4 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 8 \
--encoder timm-efficientnet-b5 \
--in_channels 8 \
--encoder_depth 5 \
--resolution 2048 \
--dropout 0.2 \
--seg_pretrain 0 \
--annotated_weight 1.0 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 1.0 \
--val_freq 1 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--use_attn 0 \
--k 128 \
--nheads 8 \
--focal 0 \
--pseudo_data_dir ../../input/processed/nihchest
# Out:
# Launched gpu 1
# Launched gpu 3
# Launched gpu 0
# Launched gpu 2
# # Train Samples: 136186 | # Val Samples: 6017
# # Parameters: 31669699
# EPOCH: 0 | LRs: {1.200000000000002e-05}
# ...
# 100%|█████████████████████████████████████████| 377/377 [02:27<00:00,  2.56it/s](trn) LOSS: 0.161623 ||
# (val) LOSS: 0.149176 | METRIC: 0.940389 || Runtime: 7699
# EPOCH: 1 | LRs: {0.00029011972373306917}
# (trn) LOSS: 0.127209 || (val) LOSS: 0.13232 | METRIC: 0.955659 || Runtime: 7680
# EPOCH: 2 | LRs: {0.00025855544764494834}
# (trn) LOSS: 0.119273 || (val) LOSS: 0.128154 | METRIC: 0.959948 || Runtime: 7686
# EPOCH: 3 | LRs: {0.0002101335360093043}
# (trn) LOSS: 0.113525 || (val) LOSS: 0.123375 | METRIC: 0.963048 || Runtime: 7685
# EPOCH: 4 | LRs: {0.00015237349584564726}
# (trn) LOSS: 0.108827 || (val) LOSS: 0.122069 | METRIC: 0.964407 || Runtime: 7697
# EPOCH: 5 | LRs: {9.424496533608708e-05}
# (trn) LOSS: 0.104642 || (val) LOSS: 0.124021 | METRIC: 0.964845 || Runtime: 7679
# ...

# %% [markdown]
# # FineTune

# %%
# !python train.py \
--data_dir ../../input/processed/data \
--logdir ../../model/v15/2048-b5-pseudoft \
--seed 0 \
--batch_size 16 \
--lr 1e-4 \
--raw_param_lr_ratio 1 \
--weight_decay 0.01 \
--epochs 3 \
--encoder timm-efficientnet-b5 \
--in_channels 8 \
--encoder_depth 5 \
--resolution 2048 \
--dropout 0.2 \
--seg_pretrain 0 \
--annotated_weight 1.0 \
--seg_pos_weight 100.0 \
--num_workers 64 \
--fold 0 \
--data_frac 1.0 \
--val_freq 1 \
--amp 1 \
--gpu_numbers '0, 1, 2, 3' \
--pretrained_path ../../model/v15/pseudo-2048-b5/best.pth \
--use_attn 0 \
--k 128 \
--nheads 8 \
--focal 0
# Out:
# Launched gpu 2
# Launched gpu 0
# Launched gpu 3
# Launched gpu 1
# # Train Samples: 24066 | # Val Samples: 6017
# # Parameters: 31669699
# <All keys matched successfully>
# Loaded Pretrained Weights from ../../model/v15/pseudo-2048-b5/best.pth
# EPOCH: 0 | LRs: {4.000000000000002e-06}
# ...
# 100%|█████████████████████████████████████████| 377/377 [02:27<00:00,  2.55it/s](trn) LOSS: 0.111593 ||
# (val) LOSS: 0.126441 | METRIC: 0.9636 || Runtime: 1539
# EPOCH: 1 | LRs: {7.58804324120573e-05}
# (trn) LOSS: 0.102707 || (val) LOSS: 0.127502 | METRIC: 0.963719 || Runtime: 1525
# EPOCH: 2 | LRs: {2.542910649510349e-05}
# (trn) LOSS: 0.098632 || (val) LOSS: 0.127443 | METRIC: 0.963481 || Runtime: 1523
# Best Val Score: 0.9637192897136295
# Runtime: 4589

# %% [markdown]
# # Infer

# %%
# !python infer.py \
--data_dir ../../input/kaggle/train \
--model_dir ../../model/final_models \
--out_dir . \
--batch_size 64 \
--num_workers 64 \
--resolution 2048 \
--fold 0 \
--folds_path folds.jl \
--train_df_path ../../input/kaggle/train.csv \
--weights 0.6-0.3-0.1 \
--dataparallel 1
# Out:
# cuda
#
# 2048-b5-pseudo2.pth
# {'logdir': '../../model/v15/0.967pseudo-2048-b5', 'seed': 0, 'batch_size': 4, 'lr': 0.0003, 'raw_param_lr_ratio': 1.0, 'weight_decay': 0.01, 'epochs': 7, 'encoder': 'timm-efficientnet-b5', 'in_channels': 8, 'encoder_depth': 5, 'resolution': 2048, 'dropout': 0.2, 'annotated_weight': 1.0, 'seg_pos_weight': 100.0, 'num_workers': 16, 'fold': 0, 'data_frac': 1.0, 'amp': True, 'gpu_numbers': '0, 1, 2, 3', 'pretrained_path': None, 'data_dir': '../../input/processed/data', 'df_dir': '../../input/kaggle/', 'val_freq': 1, 'init_random': True, 'use_attn': 0, 'k': 128, 'nheads': 8, 'focal': 0.0, 'aug': 1, 'seg_pretrain': 0, 'supcon': 0, 'pseudo_data_dir': '../../input/processed/nihchest', 'downconv': 1, 'resume': 1}
# <All keys matched successfully>
# 0.9659108943237515
#
#
# 2048-b5-pseudo.pth
# ...

# %%
# !python infer.py \
--data_dir ../../input/kaggle/test \
--model_dir ../../model/final_models \
--out_dir . \
--batch_size 64 \
--num_workers 64 \
--resolution 2048 \
--weights 0.6-0.3-0.1 \
--dataparallel 1
# Out:
# cuda
#
# 2048-b5-pseudo2.pth
# {'logdir': '../../model/v15/0.967pseudo-2048-b5', 'seed': 0, 'batch_size': 4, 'lr': 0.0003, 'raw_param_lr_ratio': 1.0, 'weight_decay': 0.01, 'epochs': 7, 'encoder': 'timm-efficientnet-b5', 'in_channels': 8, 'encoder_depth': 5, 'resolution': 2048, 'dropout': 0.2, 'annotated_weight': 1.0, 'seg_pos_weight': 100.0, 'num_workers': 16, 'fold': 0, 'data_frac': 1.0, 'amp': True, 'gpu_numbers': '0, 1, 2, 3', 'pretrained_path': None, 'data_dir': '../../input/processed/data', 'df_dir': '../../input/kaggle/', 'val_freq': 1, 'init_random': True, 'use_attn': 0, 'k': 128, 'nheads': 8, 'focal': 0.0, 'aug': 1, 'seg_pretrain': 0, 'supcon': 0, 'pseudo_data_dir': '../../input/processed/nihchest', 'downconv': 1, 'resume': 1}
# <All keys matched successfully>
# 0.9659108943237515
#
#
# 2048-b5-pseudo.pth
# ...
